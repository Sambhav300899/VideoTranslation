# %% [markdown]
# <a href="https://colab.research.google.com/github/Sambhav300899/VideoTranslation/blob/main/VideoTranslation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Translation Demo
#
# Check out the [GitHub Repo](https://github.com/Sambhav300899/VideoTranslation.git) for code, setup instructions, and more! Built by [Sambhav Rohatgi](https://sambhav300899.github.io/)

# %%
# !sudo apt-get install espeak-ng
# !git clone https://github.com/Sambhav300899/VideoTranslation.git
# %cd VideoTranslation
# !git submodule update --init --recursive
# !uv pip install -e .
# !uv pip install -r requirements.txt
# !hf download ByteDance/LatentSync-1.5 whisper/tiny.pt --local-dir LatentSync/checkpoints
# !hf download ByteDance/LatentSync-1.5 latentsync_unet.pt --local-dir LatentSync/checkpoints
# Out:
# fatal: destination path 'VideoTranslation' already exists and is not an empty directory.
# /content/VideoTranslation
# Using Python 3.12.12 environment at: /usr
# Resolved 1 package in 800ms
# Prepared 1 package in 234ms
# Installed 1 package in 0.80ms
#  + avtrans==0.1.0 (from file:///content/VideoTranslation)
# Using Python 3.12.12 environment at: /usr
# Resolved 194 packages in 6.81s
# Prepared 43 packages in 8.12s
# Uninstalled 8 packages in 104ms
# Installed 43 packages in 273ms
#  + anyascii==0.3.3
#  + coloredlogs==15.0.1
#  + coqpit-config==0.2.1
#  + coqui-tts==0.27.0
#  + coqui-tts-trainer==0.3.1
#  + dateparser==1.1.8
#  + decord==0.6.0
#  + deepcache==0.1.1
#  + docopt==0.6.2
#  + encodec==0.1.1
#  + ffmpeg-python==0.2.0
#  + gruut==2.4.0
#  + gruut-ipa==0.13.0
#  + gruut-lang-de==2.0.1
#  + gruut-lang-en==2.0.1
#  + gruut-lang-es==2.0.1
#  + gruut-lang-fr==2.0.2
#  + humanfriendly==10.0
#  + insightface==0.7.3
#  - jax==0.7.2
#  + jax==0.7.1
#  - jaxlib==0.7.2
#  + jaxlib==0.7.1
#  + jsonlines==1.2.0
#  + kornia==0.8.2
#  + kornia-rs==0.1.10
#  + mediapipe==0.10.21
#  + monotonic-alignment-search==0.2.1
#  - moviepy==1.0.3
#  + moviepy==2.1.2
#  + noisereduce==3.0.3
#  + num2words==0.5.14
#  - numpy==2.0.2
#  + numpy==1.26.3
#  + onnx==1.19.1
#  + onnxruntime-gpu==1.23.2
#  - opencv-contrib-python==4.12.0.88
#  + opencv-contrib-python==4.11.0.86
#  - opencv-python-headless==4.12.0.88
#  + opencv-python-headless==4.11.0.86
#  + pedalboard==0.9.19
#  - pillow==11.3.0
#  + pillow==10.2.0
#  + praat-parselmouth==0.4.6
#  - protobuf==5.29.5
#  + protobuf==4.25.8
#  + pysbd==0.3.4
#  + pysrt==1.1.2
#  + python-crfsuite==0.9.11
#  + sacremoses==0.1.1
#  + sounddevice==0.5.3
# Downloading 'whisper/tiny.pt' to 'LatentSync/checkpoints/.cache/huggingface/download/whisper/2bXfceQet32ashONewwCNGFRC3E=.65147644a518d12f04e32d6f3b26facc3f8dd46e5390956a9424a650c0ce22b9.incomplete'
# whisper/tiny.pt: 100% 75.6M/75.6M [00:00<00:00, 86.3MB/s]
# Download complete. Moving file to LatentSync/checkpoints/whisper/tiny.pt
# LatentSync/checkpoints/whisper/tiny.pt
# Downloading 'latentsync_unet.pt' to 'LatentSync/checkpoints/.cache/huggingface/download/HrGktaY_kGnyhqDrRVde02cPk68=.6440b49a7ccceff56cdc001f5f17605216337f5bbd66fa360139768926e23f51.incomplete'
# latentsync_unet.pt: 100% 5.07G/5.07G [00:13<00:00, 368MB/s]
# Download complete. Moving file to LatentSync/checkpoints/latentsync_unet.pt
# LatentSync/checkpoints/latentsync_unet.pt

# %%
# !gradio gradio_demo.py
# Out:
# Watching: '/content/VideoTranslation'
#
# 2025-11-21 18:49:25.620215: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-21 18:49:25.638838: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763750965.660543   11478 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763750965.667063   11478 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763750965.683772   11478 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763750965.683802   11478 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763750965.683806   11478 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763750965.683810   11478 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-21 18:49:25.688637: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.7.2 is installed, but it is not compatible with the installed jaxlib version 0.7.1, so it will not be used.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://391f13ced6b30524ea.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
